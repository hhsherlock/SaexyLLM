# %%
import whisper

# %%
model = whisper.load_model("large")
# Out:
# 100%|█████████████████████████████████████| 2.88G/2.88G [01:05<00:00, 47.3MiB/s]
# ...

# %%
modle_small = whisper.load_model("small")
# Out:
# 100%|███████████████████████████████████████| 461M/461M [00:09<00:00, 52.4MiB/s]
# ...

# %%
model_base = whisper.load_model("base")
# Out:
# /home/yaning/Documents/python_env/llm/lib/python3.13/site-packages/whisper/__init__.py:150: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
result = model_base.transcribe("/home/yaning/Documents/LLM/skip_gram/winnetou.mp3")

# %%
result["text"]
# Out:
# " Gahlmei, winnet du. Es war Anfang September und mir waren schon drei Monate dabei, der Aufgabe war aber noch nicht gelöst, obwohl die anderen Abteilung schon heeme gemacht war. Da hat er vier, gab es zwei Gründe. Zuerst einmal lacht er daran, dass wir eine sehr schwierige Gäse zu bearbeiten hatten. Der Bahn sollte durch die Prärien immer dem Keneidien fischen. Der Rüstung war so zu sagen, bis zu seinen Quälgebiet vorgezeichnet. Und von New Mexico an wurde sie eben durch die Lache, Dorteile und Besse vorgeschrieben. Unsere Abteilung dazwischen dem Keneidien und New Mexico arbeiten und wir mussten die geichene Berichtung erst einmal entdecken. Da dazu, an Helend langer Rede, an strengter Wondering und erhaufen vergleichende Messungen und Wensch, eh mir nun an der eisentliche Arbeit gehen könnten. Der zweite Grund war, wie der unsere Gesellschaft zusammengesetzt war. Ich dachte aber, dass Incent Luis von dem Oberentjenieur und den Dreissauweier aus freundlich bekriegt worden war, da d
# ...

# %%
with open("/home/yaning/Documents/LLM/skip_gram/winnetou_s.txt", "w", encoding="utf-8") as file:
    file.write(result["text"])

# %%
result_small = model_base.transcribe("/home/yaning/Documents/LLM/skip_gram/001_015_9783837174151_DESW11192227.mp3")
# print(result["text"])

# %%
result_small["text"]
# Out:
# " Gahlmei, winnet du. Es war Anfang September und mir waren schon drei Monate dabei, der Aufgabe war aber noch nicht gelöst, obwohl die anderen Abteilung schon heeme gemacht war. Da hat er vier, gab es zwei Gründe. Zuerst einmal lacht er daran, dass wir eine sehr schwierige Gäse zu bearbeiten hatten. Der Bahn sollte durch die Prärien immer dem Keneidien fischen. Der Rüstung war so zu sagen, bis zu seinen Quälgebiet vorgezeichnet. Und von New Mexico an wurde sie eben durch die Lache, Dorteile und Besse vorgeschrieben. Unsere Abteilung dazwischen dem Keneidien und New Mexico arbeiten und wir mussten die geichene Berichtung erst einmal entdecken. Da dazu, an Helend langer Rede, an strengter Wondering und erhaufen vergleichende Messungen und Wensch, eh mir nun an der eisentliche Arbeit gehen könnten. Der zweite Grund war, wie der unsere Gesellschaft zusammengesetzt war. Ich dachte aber, dass Incent Luis von dem Oberentjenieur und den Dreissauweier aus freundlich bekriegt worden war, da d
